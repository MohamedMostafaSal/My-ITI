# %% [markdown]
# <a href="https://colab.research.google.com/github/MohamedMostafaSal/My-ITI/blob/main/Data%20Visulisation/Cars_Visulisation_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install plotly
# Out:
# ...
#      |████████████████████████████████| 9.6 MB 4.3 MB/s
# ...
#      |████████████████████████████████| 357 kB 82.8 MB/s
# ...

# %%
# !pip install dash

# %%
# !pip install jupyter_dash
# Out:
# ...
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11447 sha256=fbc47b6a805db3428bfec98beb29e233131e2cc9175da6cbe3cbec4584ccd6a0
#   Stored in directory: /root/.cache/pip/wheels/f9/8d/8d/f6af3f7f9eea3553bc2fe6d53e4b287dad18b06a861ac56ddf
# Successfully built retrying
# ...

# %%
import plotly.express as px
import pandas as pd
import jupyter_dash
import dash_core_components
import dash_html_components as html
from dash import Dash,html,dcc,callback_context
from dash.dependencies import Input,Output
import matplotlib.pyplot as plt

# el styling lesa ma3amaltesh feh 7aga ana bas 7atet 7agat a3alem beeha kol styling eh bs e2ra kda le7ad manetkalem bkra
csvfileloc = 'cardetailsv3.csv'
#csvfileloc = "D:\Ahmed\ITI program\DataVisualizationProject\CarDataset\cardetailsv3.csv"
carsdf = pd.read_csv(csvfileloc)
carsdf = carsdf.dropna(how='any')

# %%
carsdfsortedbyyear = carsdf.sort_values('year')
carsdfsortedbyfuel = carsdf.sort_values('fuel')
carsdfsortedbyowner = carsdf.sort_values('owner')
carsdfsortedbyengine = carsdf.sort_values('engine')
carsdfsortedbymaxpower = carsdf.sort_values('max_power')
carsdfsortedbymileage = carsdf.sort_values('mileage')
carsdfsortedbykmdriven = carsdf.sort_values('km_driven')
carsdfsortedbysellingprice = carsdf.sort_values('selling_price')
carsdfsortedbyname = carsdf.sort_values('name')
carsdfsortedbyseats = carsdf.sort_values('seats')
carsdfsortedbytorque = carsdf.sort_values('torque')

carsdfhead= carsdf.head(10)
sellingpricevskm_driven= px.scatter(carsdfhead, x='selling_price', y='km_driven', title= 'SellingPrice vs KM driven')

Logo = 'data:image/png;base64,...'

def add_logo():
    corp_logo = html.Img(
        src=Logo, 
        style={'margin':'20px 600px 5px 5px',
              'height': '8%', 'width': '8%', 
              #'border':'1px dashed lightblue',
              'display':'inline-block'})
    return corp_logo

def make_break(num_breaks):
    br_list = [html.Br()] * num_breaks
    return br_list

#carmodels= carsdf['name'].drop_duplicates()
carmodelnames = carsdf['name'].str.split(expand=True)
carmodelnames = carmodelnames.fillna('')
carmodelnames['Type'] = carmodelnames[2] + ' ' + carmodelnames[3] + ' ' + carmodelnames[4]
carmodelnames = carmodelnames.drop([2,3,4,5,6,7,8,9],axis=1)
carmodelnames.columns = ['Maker','Model','Type']

droplistcarmodels= carmodelnames['Maker'].drop_duplicates()






 
app = jupyter_dash.JupyterDash(__name__)
colors = {
     'background': 'White',
     'text': 'Black'
}


app.layout= html.Div(style={'backgroundColor': colors['background']},
     children=[add_logo(),
     #*make_break(2),
     html.H1('Car Selling Website',style={
             'textAlign': 'center',
             'display':'inline-block',
             'color': colors['text']
         }),
         html.Div(style={
        'background-image': 'url(https://www.picsartphotoediting.com/wp-content/uploads/2019/05/Car-Background-by-ak-editz-Picsartphotoediting-8.jpg)',
        'background-repeat': 'no-repeat',
        'background-position': 'center',
        'color': 'Red' 
        },
         children= [
         html.H1('Hello World'),
         *make_break(30)
         ]),
         html.Div([
        html.Button('New Car', id='btn-nclicks-1', n_clicks=0,
        style={'font-size': '12px', 'width': '140px', 'display': 'inline-block','margin-top':'5px', 'margin-bottom': '10px', 'margin-left': '40%', 'height':'50px','textAlign': 'center','background-color':'Green'}),
        html.Button('Used Car', id='btn-nclicks-2', n_clicks=0,
        style={'font-size': '12px', 'width': '140px', 'display': 'inline-block','margin-top':'5px', 'margin-bottom': '10px','margin-left': '50px', 'margin-right': '50px', 'height':'50px','textAlign': 'center','background-color':'Blue'}),
        html.Div(id='container-button-timestamp')
])])
@app.callback(
    Output('container-button-timestamp', 'children'),
    Input('btn-nclicks-1', 'n_clicks'),
    Input('btn-nclicks-2', 'n_clicks'),
)
def displayClick(btn1, btn2):
    changed_id = [p['prop_id'] for p in callback_context.triggered][0]
    if 'btn-nclicks-1' in changed_id:
        msg = 'Button 1 was most recently clicked'
    elif 'btn-nclicks-2' in changed_id:
        msg = 'Button 2 was most recently clicked'
    else:
        msg = 'None of the buttons have been clicked yet'
    return html.Div(msg)
         #dcc.Graph(id = 'sellingpricevskm_driven', figure= sellingpricevskm_driven),


if __name__=='__main__':
    app.run_server(debug=True)
# Out:
# Dash app running on:

# %%
carsdf.describe()
# Out:
#               year  selling_price     km_driven        seats
# count  7906.000000   7.906000e+03  7.906000e+03  7906.000000
# mean   2013.983936   6.498137e+05  6.918866e+04     5.416393
# std       3.863695   8.135827e+05  5.679230e+04     0.959208
# min    1994.000000   2.999900e+04  1.000000e+00     2.000000
# 25%    2012.000000   2.700000e+05  3.500000e+04     5.000000
# 50%    2015.000000   4.500000e+05  6.000000e+04     5.000000
# 75%    2017.000000   6.900000e+05  9.542500e+04     5.000000
# max    2020.000000   1.000000e+07  2.360457e+06    14.000000

# %%
carsdf.sort_values('name')
# Out:
#                                    name  year  selling_price  km_driven  \
# 3378     Ambassador CLASSIC 1500 DSL AC  2000          75000      90000
# 4712  Ambassador Classic 2000 DSZ AC PS  1994          99000     100000
# 4974    Ambassador Grand 1500 DSZ BSIII  2008         122000      60000
# 7896    Ambassador Grand 2000 DSZ PW CL  2008         200000      80000
# 4011             Ashok Leyland Stile LE  2013         300000     200000
# ...                                 ...   ...            ...        ...
# 4324     Volvo XC40 D4 Inscription BSIV  2019        3800000      20000
# 3251             Volvo XC40 D4 R-Design  2018        3400000      22000
# 145              Volvo XC40 D4 R-Design  2018        3400000      22000
# 7516     Volvo XC60 Inscription D5 BSIV  2018        5500000      50000
# 170       Volvo XC90 T8 Excellence BSIV  2017       10000000      30000
#
#         fuel seller_type transmission         owner     mileage   engine  \
# ...

# %%
#Creating list of unique car manufacturers
CarManuf = pd.DataFrame(carsdf['name'].str.split()).apply(lambda x: x.str[0])['name'].unique()
CarManuf
# Out:
# array(['Maruti', 'Skoda', 'Honda', 'Hyundai', 'Toyota', 'Ford', 'Renault',
#        'Mahindra', 'Tata', 'Chevrolet', 'Datsun', 'Jeep', 'Mercedes-Benz',
#        'Mitsubishi', 'Audi', 'Volkswagen', 'BMW', 'Nissan', 'Lexus',
#        'Jaguar', 'Land', 'MG', 'Volvo', 'Daewoo', 'Kia', 'Fiat', 'Force',
#        'Ambassador', 'Ashok', 'Isuzu', 'Opel'], dtype=object)

# %%
#Selecting the desired car Manufacturer
desCar = CarManuf[3]
desManf = carsdf[carsdf['name'].str.startswith(desCar)].sort_values('name')
desManf
# Out:
#                                     name  year  selling_price  km_driven  \
# 7485                 Hyundai Accent CRDi  2005         130000      79000
# 1895                 Hyundai Accent CRDi  2005         100000     100000
# 4344                 Hyundai Accent CRDi  2006         120000      90000
# 5459                 Hyundai Accent CRDi  2005         200000     200000
# 5364                 Hyundai Accent CRDi  2005         130000      79000
# ...                                  ...   ...            ...        ...
# 5012       Hyundai i20 Sportz Option 1.2  2014         400000     147000
# 2196  Hyundai i20 Sportz Option 1.4 CRDi  2016         595000      60000
# 3650  Hyundai i20 Sportz Option 1.4 CRDi  2015         500000      90000
# 3464  Hyundai i20 Sportz Option 1.4 CRDi  2015         600000      40000
# 4021  Hyundai i20 Sportz Option 1.4 CRDi  2015         615000      72000
#
#         fuel seller_type transmission         owner     mileage   engine  \
# ...

# %%
Models = desManf['name'].apply(lambda x: ' '.join(x.split(' ')[1:])).unique()
Models
# Out:
# array(['Accent CRDi', 'Accent DLS', 'Accent Executive',
#        'Accent Executive CNG', 'Accent Executive LPG', 'Accent GLE',
#        'Accent GLE CNG', 'Accent GLS', 'Accent GLS 1.6',
#        'Accent GLS 1.6 ABS', 'Accent GLX', 'Accent VIVA CRDi',
#        'Creta 1.4 CRDi Base', 'Creta 1.4 CRDi S', 'Creta 1.4 CRDi S Plus',
#        'Creta 1.4 E Plus', 'Creta 1.4 EX Diesel',
#        'Creta 1.6 CRDi AT S Plus', 'Creta 1.6 CRDi AT SX Plus',
#        'Creta 1.6 CRDi Anniversary Edition', 'Creta 1.6 CRDi SX',
#        'Creta 1.6 CRDi SX Option', 'Creta 1.6 CRDi SX Plus',
#        'Creta 1.6 CRDi SX Plus Dual Tone', 'Creta 1.6 Gamma SX Plus',
#        'Creta 1.6 SX', 'Creta 1.6 SX Automatic',
#        'Creta 1.6 SX Automatic Diesel', 'Creta 1.6 SX Diesel',
#        'Creta 1.6 SX Option', 'Creta 1.6 SX Option Executive',
#        'Creta 1.6 VTVT E Plus', 'Creta 1.6 VTVT S', 'EON 1.0 Era Plus',
#        'EON 1.0 Kappa Magna Plus', 'EON 1.0 Kappa Magna Plus Optional',
# ...

# %%
#Selecting the desired car Manufacturer
desMod = Models[17]
MyCar = desManf[desManf['name'] == (desCar+' '+desMod)].sort_values('name').sort_values('year')
MyCar
# Out:
#                                   name  year  selling_price  km_driven  \
# 1544  Hyundai Creta 1.6 CRDi AT S Plus  2017        1143000      51000
#
#         fuel seller_type transmission        owner     mileage   engine  \
# 1544  Diesel  Individual    Automatic  First Owner  17.01 kmpl  1582 CC
#
#       max_power                 torque  seats
# 1544  126.2 bhp  259.9Nm@ 1900-2750rpm    5.0

# %%
import plotly.express as px
fig = px.scatter(MyCar, x="year", y="km_driven",color = 'transmission',
                 size='selling_price', hover_data=['fuel','mileage'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
